# %% [markdown]
# <a href="https://colab.research.google.com/github/lkarjun/Data-Science-from-Scratch/blob/master/Gettingdata2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

# %%
serialize = """{"title": "Data Science Book",
                "auther": "Joel Grus",
                "PublicationYear": 2019,
                "topics": ["data", "science", "data science"]}"""

# %%
deserialized = json.loads(serialize)
deserialized
# Out:
# {'PublicationYear': 2019,
#  'auther': 'Joel Grus',
#  'title': 'Data Science Book',
#  'topics': ['data', 'science', 'data science']}

# %%
from requests import get

# %%
github_user = "lkarjun"
endpoint = f"https://api.github.com/users/{github_user}/repos"

# %%
repos = json.loads(get(endpoint).text)
repos

# %%
repos
# Out:
# [{'archive_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/branches{/branch}',
#   'clone_url': 'https://github.com/lkarjun/Data-Science-from-Scratch.git',
#   'collaborators_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/contributors',
#   'created_at': '2020-06-10T13:29:53Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/downloads',
#   'events_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/forks',
#   'full_name': 'lkarjun/Data-Science-from-Scratch',
#   'git_commits_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/git/tags{/sha}',
#   'git_url': 'git://github.com/lkarjun/Data-Science-from-Scratch.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/hooks',
#   'html_url': 'https://github.com/lkarjun/Data-Science-from-Scratch',
#   'id': 271284888,
#   'issue_comment_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/labels{/name}',
#   'language': 'Jupyter Notebook',
#   'languages_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/merges',
#   'milestones_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Data-Science-from-Scratch',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzEyODQ4ODg=',
#   'notifications_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/58617251?v=4',
#    'events_url': 'https://api.github.com/users/lkarjun/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/lkarjun/followers',
#    'following_url': 'https://api.github.com/users/lkarjun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lkarjun/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/lkarjun',
#    'id': 58617251,
#    'login': 'lkarjun',
#    'node_id': 'MDQ6VXNlcjU4NjE3MjUx',
#    'organizations_url': 'https://api.github.com/users/lkarjun/orgs',
#    'received_events_url': 'https://api.github.com/users/lkarjun/received_events',
#    'repos_url': 'https://api.github.com/users/lkarjun/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/lkarjun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lkarjun/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/lkarjun'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/pulls{/number}',
#   'pushed_at': '2020-08-30T13:24:33Z',
#   'releases_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/releases{/id}',
#   'size': 11511,
#   'ssh_url': 'git@github.com:lkarjun/Data-Science-from-Scratch.git',
#   'stargazers_count': 1,
#   'stargazers_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/stargazers',
#   'statuses_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/subscribers',
#   'subscription_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/subscription',
#   'svn_url': 'https://github.com/lkarjun/Data-Science-from-Scratch',
#   'tags_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/tags',
#   'teams_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/teams',
#   'trees_url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch/git/trees{/sha}',
#   'updated_at': '2020-08-30T13:24:35Z',
#   'url': 'https://api.github.com/repos/lkarjun/Data-Science-from-Scratch',
#   'watchers': 1,
#   'watchers_count': 1},
#  {'archive_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/branches{/branch}',
#   'clone_url': 'https://github.com/lkarjun/Exam_seatAllocating.git',
#   'collaborators_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/contributors',
#   'created_at': '2020-06-04T03:55:25Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/downloads',
#   'events_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/forks',
#   'full_name': 'lkarjun/Exam_seatAllocating',
#   'git_commits_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/git/tags{/sha}',
#   'git_url': 'git://github.com/lkarjun/Exam_seatAllocating.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/hooks',
#   'html_url': 'https://github.com/lkarjun/Exam_seatAllocating',
#   'id': 269255695,
#   'issue_comment_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/merges',
#   'milestones_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/milestones{/number}',
#   'mirror_url': None,
#   'name': 'Exam_seatAllocating',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNjkyNTU2OTU=',
#   'notifications_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/58617251?v=4',
#    'events_url': 'https://api.github.com/users/lkarjun/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/lkarjun/followers',
#    'following_url': 'https://api.github.com/users/lkarjun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lkarjun/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/lkarjun',
#    'id': 58617251,
#    'login': 'lkarjun',
#    'node_id': 'MDQ6VXNlcjU4NjE3MjUx',
#    'organizations_url': 'https://api.github.com/users/lkarjun/orgs',
#    'received_events_url': 'https://api.github.com/users/lkarjun/received_events',
#    'repos_url': 'https://api.github.com/users/lkarjun/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/lkarjun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lkarjun/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/lkarjun'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/pulls{/number}',
#   'pushed_at': '2020-06-08T13:29:32Z',
#   'releases_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/releases{/id}',
#   'size': 9,
#   'ssh_url': 'git@github.com:lkarjun/Exam_seatAllocating.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/stargazers',
#   'statuses_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/subscribers',
#   'subscription_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/subscription',
#   'svn_url': 'https://github.com/lkarjun/Exam_seatAllocating',
#   'tags_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/tags',
#   'teams_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/teams',
#   'trees_url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating/git/trees{/sha}',
#   'updated_at': '2020-06-07T14:29:30Z',
#   'url': 'https://api.github.com/repos/lkarjun/Exam_seatAllocating',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/lkarjun/gmusicapi/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/lkarjun/gmusicapi/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/lkarjun/gmusicapi/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/lkarjun/gmusicapi/branches{/branch}',
#   'clone_url': 'https://github.com/lkarjun/gmusicapi.git',
#   'collaborators_url': 'https://api.github.com/repos/lkarjun/gmusicapi/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/lkarjun/gmusicapi/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/lkarjun/gmusicapi/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/lkarjun/gmusicapi/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/lkarjun/gmusicapi/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/lkarjun/gmusicapi/contributors',
#   'created_at': '2020-08-28T05:38:21Z',
#   'default_branch': 'develop',
#   'deployments_url': 'https://api.github.com/repos/lkarjun/gmusicapi/deployments',
#   'description': 'An unofficial client library for Google Music.',
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/lkarjun/gmusicapi/downloads',
#   'events_url': 'https://api.github.com/repos/lkarjun/gmusicapi/events',
#   'fork': True,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/lkarjun/gmusicapi/forks',
#   'full_name': 'lkarjun/gmusicapi',
#   'git_commits_url': 'https://api.github.com/repos/lkarjun/gmusicapi/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/lkarjun/gmusicapi/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/lkarjun/gmusicapi/git/tags{/sha}',
#   'git_url': 'git://github.com/lkarjun/gmusicapi.git',
#   'has_downloads': True,
#   'has_issues': False,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': False,
#   'homepage': 'https://unofficial-google-music-api.readthedocs.io',
#   'hooks_url': 'https://api.github.com/repos/lkarjun/gmusicapi/hooks',
#   'html_url': 'https://github.com/lkarjun/gmusicapi',
#   'id': 290960486,
#   'issue_comment_url': 'https://api.github.com/repos/lkarjun/gmusicapi/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/lkarjun/gmusicapi/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/lkarjun/gmusicapi/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/lkarjun/gmusicapi/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/lkarjun/gmusicapi/labels{/name}',
#   'language': None,
#   'languages_url': 'https://api.github.com/repos/lkarjun/gmusicapi/languages',
#   'license': {'key': 'bsd-3-clause',
#    'name': 'BSD 3-Clause "New" or "Revised" License',
#    'node_id': 'MDc6TGljZW5zZTU=',
#    'spdx_id': 'BSD-3-Clause',
#    'url': 'https://api.github.com/licenses/bsd-3-clause'},
#   'merges_url': 'https://api.github.com/repos/lkarjun/gmusicapi/merges',
#   'milestones_url': 'https://api.github.com/repos/lkarjun/gmusicapi/milestones{/number}',
#   'mirror_url': None,
#   'name': 'gmusicapi',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyOTA5NjA0ODY=',
#   'notifications_url': 'https://api.github.com/repos/lkarjun/gmusicapi/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/58617251?v=4',
#    'events_url': 'https://api.github.com/users/lkarjun/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/lkarjun/followers',
#    'following_url': 'https://api.github.com/users/lkarjun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lkarjun/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/lkarjun',
#    'id': 58617251,
#    'login': 'lkarjun',
#    'node_id': 'MDQ6VXNlcjU4NjE3MjUx',
#    'organizations_url': 'https://api.github.com/users/lkarjun/orgs',
#    'received_events_url': 'https://api.github.com/users/lkarjun/received_events',
#    'repos_url': 'https://api.github.com/users/lkarjun/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/lkarjun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lkarjun/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/lkarjun'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/lkarjun/gmusicapi/pulls{/number}',
#   'pushed_at': '2020-06-02T20:28:56Z',
#   'releases_url': 'https://api.github.com/repos/lkarjun/gmusicapi/releases{/id}',
#   'size': 4291,
#   'ssh_url': 'git@github.com:lkarjun/gmusicapi.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/lkarjun/gmusicapi/stargazers',
#   'statuses_url': 'https://api.github.com/repos/lkarjun/gmusicapi/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/lkarjun/gmusicapi/subscribers',
#   'subscription_url': 'https://api.github.com/repos/lkarjun/gmusicapi/subscription',
#   'svn_url': 'https://github.com/lkarjun/gmusicapi',
#   'tags_url': 'https://api.github.com/repos/lkarjun/gmusicapi/tags',
#   'teams_url': 'https://api.github.com/repos/lkarjun/gmusicapi/teams',
#   'trees_url': 'https://api.github.com/repos/lkarjun/gmusicapi/git/trees{/sha}',
#   'updated_at': '2020-08-28T05:38:23Z',
#   'url': 'https://api.github.com/repos/lkarjun/gmusicapi',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/lkarjun/lk/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/lkarjun/lk/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/lkarjun/lk/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/lkarjun/lk/branches{/branch}',
#   'clone_url': 'https://github.com/lkarjun/lk.git',
#   'collaborators_url': 'https://api.github.com/repos/lkarjun/lk/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/lkarjun/lk/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/lkarjun/lk/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/lkarjun/lk/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/lkarjun/lk/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/lkarjun/lk/contributors',
#   'created_at': '2020-01-23T05:00:19Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/lkarjun/lk/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/lkarjun/lk/downloads',
#   'events_url': 'https://api.github.com/repos/lkarjun/lk/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/lkarjun/lk/forks',
#   'full_name': 'lkarjun/lk',
#   'git_commits_url': 'https://api.github.com/repos/lkarjun/lk/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/lkarjun/lk/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/lkarjun/lk/git/tags{/sha}',
#   'git_url': 'git://github.com/lkarjun/lk.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': True,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/lkarjun/lk/hooks',
#   'html_url': 'https://github.com/lkarjun/lk',
#   'id': 235725906,
#   'issue_comment_url': 'https://api.github.com/repos/lkarjun/lk/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/lkarjun/lk/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/lkarjun/lk/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/lkarjun/lk/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/lkarjun/lk/labels{/name}',
#   'language': 'CSS',
#   'languages_url': 'https://api.github.com/repos/lkarjun/lk/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/lkarjun/lk/merges',
#   'milestones_url': 'https://api.github.com/repos/lkarjun/lk/milestones{/number}',
#   'mirror_url': None,
#   'name': 'lk',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyMzU3MjU5MDY=',
#   'notifications_url': 'https://api.github.com/repos/lkarjun/lk/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/58617251?v=4',
#    'events_url': 'https://api.github.com/users/lkarjun/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/lkarjun/followers',
#    'following_url': 'https://api.github.com/users/lkarjun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lkarjun/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/lkarjun',
#    'id': 58617251,
#    'login': 'lkarjun',
#    'node_id': 'MDQ6VXNlcjU4NjE3MjUx',
#    'organizations_url': 'https://api.github.com/users/lkarjun/orgs',
#    'received_events_url': 'https://api.github.com/users/lkarjun/received_events',
#    'repos_url': 'https://api.github.com/users/lkarjun/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/lkarjun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lkarjun/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/lkarjun'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/lkarjun/lk/pulls{/number}',
#   'pushed_at': '2020-08-10T02:53:51Z',
#   'releases_url': 'https://api.github.com/repos/lkarjun/lk/releases{/id}',
#   'size': 6439,
#   'ssh_url': 'git@github.com:lkarjun/lk.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/lkarjun/lk/stargazers',
#   'statuses_url': 'https://api.github.com/repos/lkarjun/lk/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/lkarjun/lk/subscribers',
#   'subscription_url': 'https://api.github.com/repos/lkarjun/lk/subscription',
#   'svn_url': 'https://github.com/lkarjun/lk',
#   'tags_url': 'https://api.github.com/repos/lkarjun/lk/tags',
#   'teams_url': 'https://api.github.com/repos/lkarjun/lk/teams',
#   'trees_url': 'https://api.github.com/repos/lkarjun/lk/git/trees{/sha}',
#   'updated_at': '2020-08-10T02:53:53Z',
#   'url': 'https://api.github.com/repos/lkarjun/lk',
#   'watchers': 0,
#   'watchers_count': 0},
#  {'archive_url': 'https://api.github.com/repos/lkarjun/usageReport/{archive_format}{/ref}',
#   'archived': False,
#   'assignees_url': 'https://api.github.com/repos/lkarjun/usageReport/assignees{/user}',
#   'blobs_url': 'https://api.github.com/repos/lkarjun/usageReport/git/blobs{/sha}',
#   'branches_url': 'https://api.github.com/repos/lkarjun/usageReport/branches{/branch}',
#   'clone_url': 'https://github.com/lkarjun/usageReport.git',
#   'collaborators_url': 'https://api.github.com/repos/lkarjun/usageReport/collaborators{/collaborator}',
#   'comments_url': 'https://api.github.com/repos/lkarjun/usageReport/comments{/number}',
#   'commits_url': 'https://api.github.com/repos/lkarjun/usageReport/commits{/sha}',
#   'compare_url': 'https://api.github.com/repos/lkarjun/usageReport/compare/{base}...{head}',
#   'contents_url': 'https://api.github.com/repos/lkarjun/usageReport/contents/{+path}',
#   'contributors_url': 'https://api.github.com/repos/lkarjun/usageReport/contributors',
#   'created_at': '2020-06-25T02:03:09Z',
#   'default_branch': 'master',
#   'deployments_url': 'https://api.github.com/repos/lkarjun/usageReport/deployments',
#   'description': None,
#   'disabled': False,
#   'downloads_url': 'https://api.github.com/repos/lkarjun/usageReport/downloads',
#   'events_url': 'https://api.github.com/repos/lkarjun/usageReport/events',
#   'fork': False,
#   'forks': 0,
#   'forks_count': 0,
#   'forks_url': 'https://api.github.com/repos/lkarjun/usageReport/forks',
#   'full_name': 'lkarjun/usageReport',
#   'git_commits_url': 'https://api.github.com/repos/lkarjun/usageReport/git/commits{/sha}',
#   'git_refs_url': 'https://api.github.com/repos/lkarjun/usageReport/git/refs{/sha}',
#   'git_tags_url': 'https://api.github.com/repos/lkarjun/usageReport/git/tags{/sha}',
#   'git_url': 'git://github.com/lkarjun/usageReport.git',
#   'has_downloads': True,
#   'has_issues': True,
#   'has_pages': False,
#   'has_projects': True,
#   'has_wiki': True,
#   'homepage': None,
#   'hooks_url': 'https://api.github.com/repos/lkarjun/usageReport/hooks',
#   'html_url': 'https://github.com/lkarjun/usageReport',
#   'id': 274809560,
#   'issue_comment_url': 'https://api.github.com/repos/lkarjun/usageReport/issues/comments{/number}',
#   'issue_events_url': 'https://api.github.com/repos/lkarjun/usageReport/issues/events{/number}',
#   'issues_url': 'https://api.github.com/repos/lkarjun/usageReport/issues{/number}',
#   'keys_url': 'https://api.github.com/repos/lkarjun/usageReport/keys{/key_id}',
#   'labels_url': 'https://api.github.com/repos/lkarjun/usageReport/labels{/name}',
#   'language': 'Python',
#   'languages_url': 'https://api.github.com/repos/lkarjun/usageReport/languages',
#   'license': None,
#   'merges_url': 'https://api.github.com/repos/lkarjun/usageReport/merges',
#   'milestones_url': 'https://api.github.com/repos/lkarjun/usageReport/milestones{/number}',
#   'mirror_url': None,
#   'name': 'usageReport',
#   'node_id': 'MDEwOlJlcG9zaXRvcnkyNzQ4MDk1NjA=',
#   'notifications_url': 'https://api.github.com/repos/lkarjun/usageReport/notifications{?since,all,participating}',
#   'open_issues': 0,
#   'open_issues_count': 0,
#   'owner': {'avatar_url': 'https://avatars2.githubusercontent.com/u/58617251?v=4',
#    'events_url': 'https://api.github.com/users/lkarjun/events{/privacy}',
#    'followers_url': 'https://api.github.com/users/lkarjun/followers',
#    'following_url': 'https://api.github.com/users/lkarjun/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/lkarjun/gists{/gist_id}',
#    'gravatar_id': '',
#    'html_url': 'https://github.com/lkarjun',
#    'id': 58617251,
#    'login': 'lkarjun',
#    'node_id': 'MDQ6VXNlcjU4NjE3MjUx',
#    'organizations_url': 'https://api.github.com/users/lkarjun/orgs',
#    'received_events_url': 'https://api.github.com/users/lkarjun/received_events',
#    'repos_url': 'https://api.github.com/users/lkarjun/repos',
#    'site_admin': False,
#    'starred_url': 'https://api.github.com/users/lkarjun/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/lkarjun/subscriptions',
#    'type': 'User',
#    'url': 'https://api.github.com/users/lkarjun'},
#   'private': False,
#   'pulls_url': 'https://api.github.com/repos/lkarjun/usageReport/pulls{/number}',
#   'pushed_at': '2020-08-11T15:09:03Z',
#   'releases_url': 'https://api.github.com/repos/lkarjun/usageReport/releases{/id}',
#   'size': 92,
#   'ssh_url': 'git@github.com:lkarjun/usageReport.git',
#   'stargazers_count': 0,
#   'stargazers_url': 'https://api.github.com/repos/lkarjun/usageReport/stargazers',
#   'statuses_url': 'https://api.github.com/repos/lkarjun/usageReport/statuses/{sha}',
#   'subscribers_url': 'https://api.github.com/repos/lkarjun/usageReport/subscribers',
#   'subscription_url': 'https://api.github.com/repos/lkarjun/usageReport/subscription',
#   'svn_url': 'https://github.com/lkarjun/usageReport',
#   'tags_url': 'https://api.github.com/repos/lkarjun/usageReport/tags',
#   'teams_url': 'https://api.github.com/repos/lkarjun/usageReport/teams',
#   'trees_url': 'https://api.github.com/repos/lkarjun/usageReport/git/trees{/sha}',
#   'updated_at': '2020-08-11T15:07:17Z',
#   'url': 'https://api.github.com/repos/lkarjun/usageReport',
#   'watchers': 0,
#   'watchers_count': 0}]
